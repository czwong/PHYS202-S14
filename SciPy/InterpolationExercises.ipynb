# %% [markdown]
# # Interpolation Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from Electrostatics import *
x,y = np.meshgrid(np.arange(-5,5.01,0.5),np.arange(-5,5.01,0.5))
Vdipole = dipolePotential(x,y,1e-9,2.)
plt.contour(x,y,Vdipole,cmap=cm.coolwarm)
plt.show()

# %% [markdown]
# 1. It is common to test functions where you know the answer they should give. Let's test the dipolePotential() function that we previously saved in Electrostatics.py to see that the function is zero along the bisector between the charges.
# First, set up a grid and evaluate the function.

# %% [markdown]
# (a) Use a boolean mask to locate the positions where x=0.

# %%
newPoint = 0.0

plt.plot(Vdipole, contour(x,y,Vdipole,cmap=cm.coolwarm), newPoint, 'r+',markersize=20,markeredgewidth=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3d6f8c4e56a5> in <module>()
#       1 newPoint = 0.0
#       2
# ----> 3 plt.plot(Vdipole, contour(x,y,Vdipole,cmap=cm.coolwarm), newPoint, 'r+',markersize=20,markeredgewidth=3)
#       4 plt.show()
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     324                 isplit = 2
#     325
# --> 326             for seg in self._plot_args(remaining[:isplit], kwargs):
#     327                 yield seg
#     328             remaining = remaining[isplit:]
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     293             x = np.arange(y.shape[0], dtype=float)
#     294
# --> 295         x, y = self._xy_from_xy(x, y)
#     296
#     297         if self.command == 'plot':
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     235         y = np.atleast_1d(y)
#     236         if x.shape[0] != y.shape[0]:
# --> 237             raise ValueError("x and y must have same first dimension")
#     238         if x.ndim > 2 or y.ndim > 2:
#     239             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %% [markdown]
# (b) Check that Vdipole for these locations is zero. i.e. print the value of Vdipole for these locations using your mask from part (a).

# %% [markdown]
# 2. Thermistors are electrical devices that measure temperature. They are made out of a material whose resistance changes very predictably with temperature. In the lab we measure the resistance of the thermistor and then compute the temperature from the engineering data that the manufacturer sends with the devices. The table below is data for a set of thermistors used in PHYS 340. The temperature values are in ∘C and the resistances in mega-Ohms, MΩ.
# Temp   Res   Temp   Res   Temp   Res   Temp   Res   Temp   Res
# ---------------------------------------------------------------
#  10   3.239   16   2.610   22   2.169   28   1.857   34   1.634
#  11   3.118   17   2.526   23   2.110   29   1.815   35   1.603
#  12   3.004   18   2.446   24   2.053   30   1.774   36   1.574
#  13   2.897   19   2.371   25   2.000   31   1.736   37   1.547
#  14   2.795   20   2.300   26   1.950   32   1.700   38   1.521
#  15   2.700   21   2.233   27   1.902   33   1.666   39   1.496

# %% [markdown]
# (a) Let's turn this look-up table into a continuous function. Write a reusable function Temp(Resistance) that takes any value of Resistance and returns the interpolated temperature. Be sure to include a docstring in your function.

# %%
def Temp(Resistance):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.interpolate import interp1d 
    Temperature = np.arange(10, 40)
    Res = [3.239, 3.118, 3.004, 2.897, 2.795, 2.700, 2.610, 2.526, 2.446, 2.371, 2.300, 2.233, 2.169, 2.110, 2.053, 2.000, 1.950, 1.902, 1.857, 1.815, 1.774, 1.736, 1.700, 1.666, 1.634, 1.603, 1.574, 1.547, 1.521, 1.496]
    Temp = interp1d(Temperature[-1:0:1], Res[-1:0:1])

# %% [markdown]
# (b) Show that the function returns expected values, including some from the table for a few specific input resistances.

# %%
print Temp(3.239)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6bbfe7834683> in <module>()
# ----> 1 print Temp(3.239)
#
# <ipython-input-3-cb76132800f4> in Temp(Resistance)
#       5     Temperature = np.arange(10, 40)
#       6     Res = [3.239, 3.118, 3.004, 2.897, 2.795, 2.700, 2.610, 2.526, 2.446, 2.371, 2.300, 2.233, 2.169, 2.110, 2.053, 2.000, 1.950, 1.902, 1.857, 1.815, 1.774, 1.736, 1.700, 1.666, 1.634, 1.603, 1.574, 1.547, 1.521, 1.496]
# ----> 7     Temp = interp1d(Temperature[-1:0:1], Res[-1:0:1])
#
# /Applications/anaconda/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in __init__(self, x, y, kind, axis, copy, bounds_error, fill_value)
#     364         # Interpolation goes internally along the first axis
#     365         self.y = y
# --> 366         y = self._reshape_yi(y)
#     367
#     368         # Adjust to interpolation kind; store reference to *unbound*
#
# /Applications/anaconda/lib/python2.7/site-packages/scipy/interpolate/polyint.pyc in _reshape_yi(self, yi, check)
#      78                                            self._y_extra_shape[:-self._y_axis])
#      79             raise ValueError("Data must be of shape %s" % ok_shape)
# ---> 80         return yi.reshape((yi.shape[0], -1))
#      81
#      82     def _set_yi(self, yi, xi=None, axis=None):
#
# ValueError: total size of new array must be unchanged

# %% [markdown]
# (c) Plot Temp(Resistance) vs. Resistance for a reasonable range of Resistance with reasonably fine sampling. Include as an annotation on the plot the value of the temperature for a resistance of 1.75 MΩ. (It's up to you to decide what "reasonable" means in both cases.)

# %%
Temperature = np.arange(10, 40)
Res = [3.239, 3.118, 3.004, 2.897, 2.795, 2.700, 2.610, 2.526, 2.446, 2.371, 2.300, 2.233, 2.169, 2.110, 2.053, 2.000, 1.950, 1.902, 1.857, 1.815, 1.774, 1.736, 1.700, 1.666, 1.634, 1.603, 1.574, 1.547, 1.521, 1.496]
plt.plot(Temperature, Res)
plt.show()
