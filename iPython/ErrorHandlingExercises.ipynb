# %% [markdown]
# 1. Find a partner. Choose a driver and a navigator. The driver should copy their Battleship code to a cell in the driver's ErrorHandlingExercises notebook. The driver should explain to the navigator the basics of how their program works. Work together to add some error handling to the program. Include a markdown cell identifying the driver and navigator. When you are done, switch roles and let the navigator be the driver and vice versa. At the end you should both have a Battleship program that includes some error handling.

# %%
from random import randint
from ipythonblocks import colors
from ipythonblocks import BlockGrid

board = []
vert_hori = 0
ship_length = []


print "Let's play Battleship!"
grid = BlockGrid(10, 10, fill=(173, 216, 230))
grid.show()

def random_row(board):
    return randint(0, (grid.width))

def random_col(board):
    return randint(0, (grid.height))


ship_row = random_row(board)
ship_col = random_col(board)

def set_length(ship_r, ship_c, vh):
    temp_r = ship_r
    temp_c = ship_c
    length = randint(2, 4)
    if vh == 0:
        if temp_c < 9 - length:
            for i in range(0, length):
                print i,'one',temp_r,temp_c #this is to check for the bug because the ship length may be going out of the board horizontally.
                ship_length.append(grid[temp_r,temp_c])
                temp_c += 1
    else:
        if temp_r < 9 - length:
            for i in range(0, length):
                print i,'two',temp_r,temp_c #this is to check for the bug because the ship length may be going out of the board vertically.
                ship_length.append(grid[temp_r,temp_c])
                temp_r += 1
            
vert_hori = randint(0,1)
set_length(ship_row, ship_col, vert_hori)


for turn in range(8):
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    
    for i in range(len(ship_length)):
        if guess_row == ship_length[i].row and guess_col == ship_length[i].col:
            grid[guess_row,guess_col] = colors['Red']
            print "Congratulations! You hit my battleship!"
            print '(' + str(ship_row) + ',' + str(ship_col) + ')'
            break

        else:
            if (guess_row < 0 or guess_row > 9) or (guess_col < 0 or guess_col > 9):
                print "Oops, that's not even in the ocean."
                print "Turn", turn + 1
                break
            elif(grid[guess_row,guess_col] == colors['Red']):
                print "You hit this part already!"
                print "Turn", turn + 1
                break
            else:
                print "You missed my battleship!"
                grid[guess_row,guess_col] = colors['Blue']
                print "Turn", turn + 1
                break
    
    if turn == 7:
        print "Game Over"
        for i in range(len(ship_length)):
            grid[ship_length[i].row,ship_length[i].col] = colors['Red']
            grid.show()
        for i in range(len(ship_length)):
            print ship_length[i].row
            print ship_length[i].col
        break
    else:
        grid.show()
# Out:
# Let's play Battleship!
# ...

# %% [markdown]
# Driver: Chris Wong
# Navigator: Chris Wong
#
# I tried to fix my own battleship code since there is a inconsistent bug. Sometimes I can input the numbers and play with the game and other times when I input the numbers nothing shows up on the board. I still cannot figure the logic behind the length of the ship interfering with the length of the board.

# %% [markdown]
# 2. Here is a function which takes a filename, opens the file, reads the result, closes the file, and returns the contents. It should look something like this:
#
#
# Use runtime error handling concepts to improve this function, so that it does the following:
#     -raises an informative custom error if the file doesn't exist
#     -uses try, except, else, amd/or finally to safely return the file's contents & close the file if necessary.
#     -add a keyword safe which defaults to False. If the function is called with safe=True, then return an empty string if the file doesn't exist.

# %%
def read_all_from_file(filename, safe=False):
    import os
    if safe==True and not os.path.exists(filename):
        return ""
    if not os.path.exists(filename):
        raise ValueError("'%s' does not exist"%format(filename))
    try:
        f = open(filename)
        contents = f.read()
        f.close()
        return contents
    except IOError as err:
        print err
        print "File does not exist: ",err.filename
        return None

# %%
read_all_from_file('tmp.txt')

# %%
read_all_from_file('file.which.does.not.exist')

# %%
read_all_from_file('file.which.does.not.exist', safe=True)
