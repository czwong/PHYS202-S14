# %%
#Disgraceful alternative function to make the graph. It did not work...

#def Grid(x,y,r,b):
    #grid = BlockGrid(x, y, fill=(0,0,0))
    #redblocks = []
    #blueblocks = []
    #for i in range(grid.height):
        #for j in range(grid.width):
            #random_color = randint(0,3)
            #print i,j
            #if (random_color == 0) or (random_color == 3):
                #redblocks.append(grid[(i+randint(0,(grid.height-1-i))),(j+randint(0,(grid.width-1-i)))])
            #elif (random_color == 1) or (random_color == 2):
                #blueblocks.append(grid[(i+randint(0,(grid.height-1-i))),(j+randint(0,((grid.width-1)-i)))])
    #for i in range(r):
        #row = redblocks[i].row
        #col = redblocks[i].col
        #grid[row,col] = colors['Red']
    #for i in range(b):
        #row = blueblocks[i].row
        #col = blueblocks[i].col
        #grid[row,col] = colors['Blue']
        
    #grid.show()

# %%
from random import randint
from ipythonblocks import colors
from ipythonblocks import BlockGrid
from IPython.html import widgets
from IPython.display import display
from IPython.html.widgets import interact, interactive 
from IPython.display import clear_output

# %%
def equal_color(a,b):
    if (a.red,a.green,a.blue) == (b.red,b.green,b.blue):
        return True
    else:
        return False

# %%
def equal_black(a):
    if (a.red == 0) and (a.green == 0) and (a.blue == 0):
        return True
    else:
        return False

# %%
def satisfaction(grid,i,j):
    GridSize = grid.width - 1
    if grid[i,j].rgb != black:
        if i == 0 or j == 0 or i == GridSize or j == GridSize: #Any of the corners and edge pieces
            #Corners
            if i == 0 and j == 0:
                sat = 0 #More grids of equal color, the more satisfied they are
                MaxNeighbors = 3 #Neighbors around the block that aren't black(empty)
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1 
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j+1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction #This is the actual satisfaction point
            elif i == 0 and j == GridSize:
                sat = 0
                MaxNeighbors = 3
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif (i == GridSize and j == 0):
                sat = 0
                MaxNeighbors = 3
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif (i == GridSize and j == GridSize):
                sat = 0
                MaxNeighbors = 3
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
        elif (i != 0 and j != 0) or (i != 0 and j != GridSize) or (i != Gridsize and j != 0)\
        or (i != Gridsize and j != Gridsize):
            #Edge Pieces
            if i == 0 and j != 0 and j!=GridSize:
                sat = 0
                MaxNeigbors = 5
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif j == 0 and i!=0 and i!=GridSize:
                sat = 0
                MaxNeigbors = 5
                if equal_color(grid[i+1,j],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif i == GridSize and j !=0 and j!=GridSize:
                sat = 0
                MaxNeigbors = 5
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif j == GridSize and i!=0 and i != GridSize:
                sat = 0
                MaxNeigbors = 5
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat+ 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            
            #MIDDLE SQUARES
            else:
                sat = 0
                MaxNeighbors = 8
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat+ 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i, j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i, j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1

                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
    else:
        return None

# %%
def mover(grid,threshold):
    GridSize = grid.width - 1
    for i in range(grid.height):
        for j in range(grid.width):
            random_grid = randint(0,7) #Used for moving block to nearest empty space either up, left, right, or down
            if satisfaction(grid,i,j) < threshold:
                if i == 0 and j == 0:
                    if random_grid <= 3:
                        if equal_black(grid[i+1,j]): #Checks to see if neighboring blocks are black(empty)
                            grid[i,j] = grid[i+1,j] #Moves to black spot(empty spot)
                            grid[i,j] = black #Previous spot now becomes black
                    if random_grid > 3 and random_grid < 6:
                        if equal_black(grid[i+1,j+1]):
                            grid[i,j] = grid[i+1,j+1]
                            grid[i,j] = black
                    if random_grid >= 6:
                        if equal_black(grid[i,j+1]):
                            grid[i,j] = grid[i,j+1]
                            grid[i,j] = black
                elif i == GridSize and j ==0:
                    if random_grid <= 3:
                        if equal_black(grid[i-1,j]):
                            grid[i,j] = grid[i-1,j]
                            grid[i,j] = black
                    if random_grid > 3 and random_grid < 6:
                        if equal_black(grid[i-1,j+1]):
                            grid[i,j] = grid[i-1,j+1]
                            grid[i,j] = black
                    if random_grid >= 6:
                        if equal_black(grid[i,j+1]):
                            grid[i,j] = grid[i,j+1]
                            grid[i,j] = black
                elif i == GridSize and j == GridSize:
                    if random_grid <= 3:
                        if equal_black(grid[i,j-1]):
                            grid[i,j] = grid[i,j-1]
                            grid[i,j] = black
                    if random_grid > 3 and random_grid < 6:
                        if equal_black(grid[i-1,j-1]):
                            grid[i,j] = grid[i-1,j-1]
                            grid[i,j] = black
                    if random_grid >= 6:
                        if equal_black(grid[i-1,j]):
                            grid[i,j] = grid[i-1,j]
                            grid[i,j] = black
                elif i == 0 and j == GridSize:
                    if random_grid <= 3:
                        if equal_black(grid[i,j-1]):
                            grid[i,j] = grid[i,j-1]
                            grid[i,j] = black
                    if random_grid > 3 and random_grid < 6:
                        if equal_black(grid[i+1,j-1]):
                            grid[i,j] = grid[i+1,j-1]
                            grid[i,j] = black
                    if random_grid >= 6:
                        if equal_black(grid[i+1,j]):
                            grid[i,j] = grid[i+1,j]
                            grid[i,j] = black
                elif i == 0 and j != 0 and j!= GridSize:
                    if random_grid <= 1:
                        if equal_black(grid[i,j-1]):
                            grid[i,j] = grid[i,j-1]
                            grid[i,j] = black
                    if random_grid == 2 or random_grid == 3:
                        if equal_black(grid[i+1,j-1]):
                            grid[i,j] = grid[i+1,j-1]
                            grid[i,j] = black
                    if random_grid == 4 or random_grid == 5:
                        if equal_black(grid[i+1,j]):
                            grid[i,j] = grid[i+1,j]
                            grid[i,j] = black
                    if random_grid == 6:
                        if equal_black(grid[i+1,j+1]):
                            grid[i,j] = grid[i+1,j+1]
                            grid[i,j] = black
                    if random_grid == 7:
                        if equal_black(grid[i,j+1]):
                            grid[i,j] = grid[i,j+1]
                            grid[i,j] = black
                elif j == GridSize and i != 0 and i!= GridSize:
                    if random_grid <= 1:
                        if equal_black(grid[i-1,j]):
                            grid[i,j] = grid[i-1,j]
                            grid[i,j] = black
                    if random_grid == 2 or random_grid == 3:
                        if equal_black(grid[i-1,j-1]):
                            grid[i,j] = grid[i-1,j-1]
                            grid[i,j] = black
                    if random_grid == 4 or random_grid == 5:
                        if equal_black(grid[i,j-1]):
                            grid[i,j] = grid[i,j-1]
                            grid[i,j] = black
                    if random_grid == 6:
                        if equal_black(grid[i+1,j-1]):
                            grid[i,j] = grid[i+1,j-1]
                            grid[i,j] = black
                    if random_grid == 7:
                        if equal_black(grid[i+1,j]):
                            grid[i,j] = grid[i+1,j]
                            grid[i,j] = black
                elif i == GridSize and j != 0 and j!= GridSize:
                    if random_grid <= 1:
                        if equal_black(grid[i,j-1]):
                            grid[i,j] = grid[i,j-1]
                            grid[i,j] = black
                    if random_grid == 2 or random_grid == 3:
                        if equal_black(grid[i-1,j-1]):
                            grid[i,j] = grid[i-1,j-1]
                            grid[i,j] = black
                    if random_grid == 4 or random_grid == 5:
                        if equal_black(grid[i-1,j]):
                            grid[i,j] = grid[i-1,j]
                            grid[i,j] = black
                    if random_grid == 6:
                        if equal_black(grid[i-1,j+1]):
                            grid[i,j] = grid[i-1,j+1]
                            grid[i,j] = black
                    if random_grid == 7:
                        if equal_black(grid[i,j+1]):
                            grid[i,j] = grid[i,j+1]
                            grid[i,j] = black
                elif j == 0 and i != 0 and i!= GridSize:
                    if random_grid <= 1:
                        if equal_black(grid[i-1,j]):
                            grid[i,j] = grid[i-1,j]
                            grid[i,j] = black
                    if random_grid == 2 or random_grid == 3:
                        if equal_black(grid[i-1,j+1]):
                            grid[i,j] = grid[i-1,j+1]
                            grid[i,j] = black
                    if random_grid == 4 or random_grid == 5:
                        if equal_black(grid[i,j+1]):
                            grid[i,j] = grid[i,j+1]
                            grid[i,j] = black
                    if random_grid == 6:
                        if equal_black(grid[i+1,j+1]):
                            grid[i,j] = grid[i+1,j+1]
                            grid[i,j] = black
                    if random_grid == 7:
                        if equal_black(grid[i+1,j]):
                            grid[i,j] = grid[i+1,j]
                            grid[i,j] = black
                else:
                    grid[i,j] = grid[i+1,j] or grid[i,j+1] or grid[i-1,j] or grid[i,j-1]\
                    or grid[i+1,j+1] or grid[i-1,j+1] or grid[i-1,j-1] or grid[i+1,j-1]
                    if random_grid == 0:
                        if equal_black(grid[i+1,j]):
                            grid[i,j] = grid[i+1,j]
                            grid[i,j] = black
                    if random_grid == 1:
                        if equal_black(grid[i,j+1]):
                            grid[i,j] = grid[i,j+1]
                            grid[i,j] = black
                    if random_grid == 2:
                        if equal_black(grid[i-1,j]):
                            grid[i,j] = grid[i-1,j]
                            grid[i,j] = black
                    if random_grid == 3:
                        if equal_black(grid[i,j-1]):
                            grid[i,j] = grid[i,j-1]
                            grid[i,j] = black
                    if random_grid == 4:
                        if equal_black(grid[i+1,j+1]):
                            grid[i,j] = grid[i+1,j+1]
                            grid[i,j] = black
                    if random_grid == 5:
                        if equal_black(grid[i-1,j+1]):
                            grid[i,j] = grid[i-1,j+1]
                            grid[i,j] = black
                    if random_grid == 6:
                        if equal_black(grid[i-1,j-1]):
                            grid[i,j] = grid[i-1,j-1]
                            grid[i,j] = black
                    if random_grid == 7:
                        if equal_black(grid[i+1,j-1]):
                            grid[i,j] = grid[i+1,j-1]
                            grid[i,j] = black

# %%
black = (0,0,0)
red = (255,0,0)
green = (0,128,0)
blue = (0,0,255)

def make_grid(pop_density,blue_concentration,size,threshold,iteration):
    grid = BlockGrid(size, size, fill=(0,0,0),block_size=300/size) 
    total = size**2 #total= total amount of blocks
    empties = (total * pop_density)/100
    blues_reds = total - empties #blues_reds= total amount of agents
    blues = (blue_concentration * blues_reds)/100
    reds = blues_reds - blues

    #create random locations for blue agents
    count_blues = 0
    while count_blues < blues: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are made blue
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block blue if it is empty
            grid[row,col] = blue
            count_blues += 1

    #create random locations for red agents
    count_reds = 0
    while count_reds < reds: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are red
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block red if it is empty
            grid[row,col] = red
            count_reds += 1


    while iteration > 0:
        mover(grid,threshold)
        iteration = iteration - 1
        clear_output()
    grid.show()
    
v = interact(make_grid,pop_density=(0,100,1),blue_concentration=(0,70,1),\
             size=(5,50,1),threshold=(0,.8,.05),iteration=(0,200,5))
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4dcaeee5-0989-449d-b1c3-f5e638567a56 td {border: 1px solid white;}</style><table id="blocks4dcaeee5-0989-449d-b1c3-f5e638567a56" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 11px; height: 11px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 11px; height: 11px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 11px; height: 11px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 11px; height: 11px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 11px; height: 11px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 11px; height: 11px;background-color: rgb(0, 0, 0);"></td><td ti
# ...

# %%
from random import randint
from ipythonblocks import colors
from ipythonblocks import BlockGrid
from IPython.html import widgets
from IPython.display import display
from IPython.html.widgets import interact, interactive 
from IPython.display import clear_output

# %%
black = (0,0,0)
red = (255,0,0)
green = (0,128,0)
blue = (0,0,255)

def make_grid(pop_density,blue_concentration,size,iteration):
    grid = BlockGrid(size, size, fill=(0,0,0),block_size=300/size) 
    total = size**2 #total= total amount of blocks
    empties = (total * pop_density)/100
    blues_reds = total - empties #blues_reds= total amount of agents
    blues = (blue_concentration * blues_reds)/100
    reds = blues_reds - blues

    #create random locations for blue agents
    Grid = grid.width - 1
    
    count_blues = 0
    while count_blues < blues: #iterates through random locations of blockgrid
        random_spot = randint(0,3)
        if random_spot == 0:    
            row = randint(Grid-(Grid/4),Grid) #until the right amount of blocks are made blue
            col = randint(Grid-(Grid/2),Grid)
            if grid[row,col].rgb == black: #only makes the block blue if it is empty
                grid[row,col] = blue
                count_blues += 1
        if random_spot == 2:    
            row = randint(Grid-(Grid/2),Grid) #until the right amount of blocks are made blue
            col = randint(Grid-(Grid/2),Grid)
            if grid[row,col].rgb == black: #only makes the block blue if it is empty
                grid[row,col] = blue
                count_blues += 1
        if random_spot == 1 or random_spot == 3:    
            row = randint(0,grid.height-1) #until the right amount of blocks are made blue
            col = randint(Grid-(Grid/2),Grid)
            if grid[row,col].rgb == black: #only makes the block blue if it is empty
                grid[row,col] = blue
                count_blues += 1

    #create random locations for red agents
    count_reds = 0
    while count_reds < reds: #iterates through random locations of blockgrid
        random_spot = randint(0,3)
        if random_spot == 0:    
            row = randint(Grid-(Grid/8),Grid) #until the right amount of blocks are red
            col = randint(0,Grid/2)
            if grid[row,col].rgb == black: #only makes the block red if it is empty
                grid[row,col] = red
                count_reds += 1
        if random_spot == 3:    
            row = randint(Grid-(Grid/8),Grid) #until the right amount of blocks are red
            col = randint(0,Grid/2)
            if grid[row,col].rgb == black: #only makes the block red if it is empty
                grid[row,col] = red
                count_reds += 1
        if random_spot == 1 or random_spot == 2:    
            row = randint(Grid-(Grid/4),Grid) #until the right amount of blocks are red
            col = randint(Grid/8,Grid/4)
            if grid[row,col].rgb == black: #only makes the block red if it is empty
                grid[row,col] = red
                count_reds += 1
    
    grid.show()

# %%
##It should create a distribution of blue on the very right side of the graph and red on the left to the middle of the graph
make_grid(pop_density=44,blue_concentration=40,size=20,iteration=0)
