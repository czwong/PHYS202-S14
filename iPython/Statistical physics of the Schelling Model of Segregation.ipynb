# %%
from random import randint
from ipythonblocks import colors
from ipythonblocks import BlockGrid

grid = BlockGrid(10, 10, fill=(173, 216, 230))

def random_people(board):
    return randint(15, (grid.width)*2)

row_number = randint(0, (grid.height))
column_number = randint(0, (grid.width))
grid[row_number, column_number] = colors['Red']

#Create a random amount of block across the board from the range of 15 to 20
grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf1739de9-5efe-4e8e-9915-579016088d38 td {border: 1px solid white;}</style><table id="blocksf1739de9-5efe-4e8e-9915-579016088d38" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 2
# ...

# %%
def equal_color(a,b):
    if (a.red == b.red) and (a.green == b.green) and (a.blue == b.blue): 
        return True
    else:
        return False

# %%
def equal_black(a):
    if (a.red == 0) and (a.green == 0) and (a.blue == 0):
        return True
    else:
        return False

# %%
def satisfaction():
    block = []
    GridSize = grid.width 
    if i == 0 or j == 0 or i == GridSize or j == GridSize:
        #Corners
        if i == 0 and j == 0:
            sat = 0
            MaxNeighbors = 3
            if equal_color(grid[i+1,j],grid[i,j]):
                sat = sat + 1 
            elif equal_black(grid[i+1,j]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i,j+1],grid[i,j]): 
                sat = sat + 1 
            elif equal_black(grid[i,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors)
            return satisfaction
            block.append(str(satisfaction))
        elif i == 0 and j == GridSize:
            sat = 0
            MaxNeighbors = 3
            if equal_color(grid[i,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j-1],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i+1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors)
            return satisfaction
            block.append(str(satisfaction))
        elif (i == GridSize and j == 0):
            sat = 0
            MaxNeighbors = 3
            if equal_color(grid[i,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors)
            return satisfaction
            block.append(str(satisfaction))
        elif (i == GridSize and j == GridSize):
            sat = 0
            MaxNeighbors = 3
            if equal_color(grid[i-1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors)
            return satisfaction
            block.append(str(satisfaction))
    elif (i != 0 and j != 0) or (i != 0 and j != GridSize) or (i != Gridsize and j != 0) or (i != Gridsize and j != Gridsize):
        #Edge Pieces
        if i == 0 and j != 0 and j!=GridSize:
            sat = 0
            MaxNeigbors = 5
            if equal_color(grid[i,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j-1],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i+1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i,j-1],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors)
            return satisfaction
            block.append(str(satisfaction))
        elif j == 0 and i!=0 and i!=GridSize:
            sat = 0
            if equal_color(grid[i+1,j],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i+1,j]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors)
            return satisfaction
            block.append(str(satisfaction))
        elif i == GridSize and j !=0 and j!=GridSize:
            sat = 0
            if equal_color(grid[i,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i-1,j]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i,j-1],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j-1],grid[i,j]): 
                sat = sat + 1
            elif equal_black(grid[i-1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors) 
            return satisfaction
            block.append(str(satisfaction))
        elif j == GridSize and i!=0 and i != GridSize:
            sat = 0
            if equal_color(grid[i+1,j],grid[i,j]):
                sat = sat+ 1
            elif equal_black(grid[i+1,j]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i+1,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
            if equal_color(grid[i-1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j]):
                MaxNeighbors = MaxNeigbors - 1
            satisfaction = float(sat) / float(MaxNeighbors)
            return satisfaction
            block.append(str(satisfaction))
    else:
        #MIDDLE SQUARES
        sat = 0
        MaxNeighbors = 8
        if equal_color(grid[i+1,j],grid[i,j]):
            sat = sat+ 1
        elif equal_black(grid[i+1,j]):
                MaxNeighbors = MaxNeigbors - 1
        if equal_color(grid[i+1,j+1],grid[i,j]):
            sat = sat + 1
        elif equal_black(grid[i+1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
        if equal_color(grid[i,j+1],grid[i,j]):
            sat = sat + 1
        elif equal_black(grid[i,j+1]):
                MaxNeighbors = MaxNeigbors - 1
        if equal_color(grid[i-1,j+1],grid[i,j]):
            sat = sat + 1
        elif equal_black(grid[i-1,j+1]):
                MaxNeighbors = MaxNeigbors - 1
        if equal_color(grid[i-1,j],grid[i,j]):
            sat = sat + 1
        elif equal_black(grid[i-1,j]):
                MaxNeighbors = MaxNeigbors - 1
        if equal_color(grid[i-1,j-1],grid[i,j]):
            sat = sat + 1
        elif equal_black(grid[i-1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
        if equal_color(grid[i, j-1],grid[i,j]):
            sat = sat + 1
        elif equal_black(grid[i, j-1]):
                MaxNeighbors = MaxNeigbors - 1
        if equal_color(grid[i+1,j-1],grid[i,j]):
            sat = sat + 1
        elif equal_black(grid[i+1,j-1]):
                MaxNeighbors = MaxNeigbors - 1
        satisfaction = float(sat) / float(MaxNeighbors)
        return satisfaction
        block.append(str(satisfaction))

# %%
def move_agents(grid,threshold):
    for i in range(len(movers)):
        print "iteration"
        print nulls
    for null in nulls:
        original_color = grid[movers[0]].rgb #move the mover to a null and replace null with 
        mover grid[null] = grid[movers[0]]
        grid[movers[0]] = white 
        if satisfaction(grid, null[1],null[0]) < threshold:
            grid[null] = white #if mover is not satisfied move it back to where it was before
            grid[movers[0]] = original_color
            if nulls[len(nulls) - 1] == null: # if mover has no place to go then keep it where it is 
                movers.remove(movers[0])
                print null
            else:
                nulls.remove(null)
                nulls.append(movers[0])
                movers.remove(movers[0])
                break

# %%
def mover(threshold):
    for element in block:
        if element >= threshold:
            #for i in grid.width:
                #for j in grid.height:
            if (i and j) < GridSize:
                grid[i,j] = grid[i+1,j] or grid[i+1,j+1] or grid[i,j+1]
            elif i != 0 or j != 0 or i!= GridSize or j != Gridsize:
                grid[i,j] = grid[i+1,j] or grid[i,j+1] or grid [i-1,j] or grid[i,j-1] or grid[i+1,j+1] or grid[i-1,j+1] or grid[i-1,j-1] or grid[i+1,j-1]
            elif i == Gridsize and j ==0:
                grid[i,j] = grid[i-1,j] or grid[i-1,j+1] or grid[i,j+1]
            elif i == GridSize and j == GridSize:
                grid[i,j] = grid[i,j-1] or grid[i-1,j-1] or grid[i-1,j]
            elif i == 0 and j == GridSize:
                grid[i,j] = grid[i,j-1] or grid[i+1,j-1] or grid[i+1,j]
            elif i == 0 and j != 0 and j!= GridSize:
                grid[i,j] = grid[i,j-1] or grid[i+1,j-1] or grid[i+1,j] or grid[i+1,j+1] or grid[i,j+1]
            elif j == GridSize and i != 0 and i!= GridSize:
                grid[i,j] = grid[i-1,j] or grid[i-1,j-1] or grid[i,j-1] or grid[i+1,j-1] or grid[i+1,j]
            elif i == GridSize and j != 0 and j!= GridSize:
                grid[i,j] = grid[i,j-1] or grid[i-1,j-1] or grid[i-1,j] or grid[i-1,j+1] or grid[i,j+1]
            elif j == 0 and i != 0 and i!= GridSize:
                grid[i,j] = grid[i-1,j] or grid[i-1,j+1] or grid[i,j+1] or grid[i+1,j+1] or grid[i+1,j]
            elif grid[i,j] == (0,0,0):
                grid[i,j] = grid[i,j]
        
    


#if satisfied increase or decrease block count by 1 in the x or y axis
#need to implement that it knows which block satisfies threshold
