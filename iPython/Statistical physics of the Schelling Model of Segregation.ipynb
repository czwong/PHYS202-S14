# %%
from random import randint
from ipythonblocks import colors
from ipythonblocks import BlockGrid

# %%
def make_system(pop_density,blue_concentration,size):
    grid= BlockGrid(size, size, fill=(0,0,0),block_size=300/size) 
    total = size**2 #total= total amount of blocks
    empties = (total * pop_density)/100
    blues_reds = total - empties #blues_reds= total amount of agents
    blues = (blue_concentration * blues_reds)/100
    reds = blues_reds - blues
    
    #create random locations for blue agents
    count_blues = 0
    while count_blues < blues: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are made blue
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block blue if it is empty
            system[row,col] = blue
            count_blues += 1
    
    #create random locations for red agents
    count_reds = 0
    while count_reds < reds: #iterates through random locations of blockgrid
        row = random_row(system) #until the right amount of blocks are red
        col = random_col(system)
        if system[row,col].rgb == black: #only makes the block red if it is empty
            system[row,col] = red
            count_reds += 1
    
    system.show()
    return system,pop_density,blue_concentration,size

# %%
def Grid(x,y,r,b):
    grid = BlockGrid(x, y, fill=(0,0,0))
    redblocks = []
    blueblocks = []
    for i in range(grid.height):
        for j in range(grid.width):
            random_color = randint(0,3)
            print i,j
            if (random_color == 0) or (random_color == 3):
                redblocks.append(grid[(i+randint(0,(grid.height-1-i))),(j+randint(0,(grid.width-1-i)))])
            elif (random_color == 1) or (random_color == 2):
                blueblocks.append(grid[(i+randint(0,(grid.height-1-i))),(j+randint(0,((grid.width-1)-i)))])
    for i in range(r):
        row = redblocks[i].row
        col = redblocks[i].col
        grid[row,col] = colors['Red']
    for i in range(b):
        row = blueblocks[i].row
        col = blueblocks[i].col
        grid[row,col] = colors['Blue']
        
    grid.show()

# %%
red = len(range(r))
blue = len(range(b))
redblocks.append(grid[i-randint(0,((grid.height))),j-randint(0,)])
blueblocks.append(grid[i-randint(0,),j-randint(0,)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0f3598bdfaba> in <module>()
# ----> 1 red = len(range(r))
#       2 blue = len(range(b))
#       3 redblocks.append(grid[i-randint(0,((grid.height))),j-randint(0,)])
#       4 blueblocks.append(grid[i-randint(0,),j-randint(0,)])
#
# NameError: name 'r' is not defined

# %%
def mover(grid,threshold):
    GridSize = grid.width - 1
    if satisfication(grid,i,j) <= threshold:
        if (i < GridSize) and (j < GridSize):
            grid[i,j] = grid[i+1,j] or grid[i+1,j+1] or grid[i,j+1]
        elif !(i == 0 or j == 0 or i== GridSize or j == Gridsize):
            grid[i,j] = grid[i+1,j] or grid[i,j+1] or grid [i-1,j] or grid[i,j-1] or grid[i+1,j+1] or grid[i-1,j+1] or grid[i-1,j-1] or grid[i+1,j-1]
        elif i == GridSize and j ==0:
            grid[i,j] = grid[i-1,j] or grid[i-1,j+1] or grid[i,j+1]
        elif i == GridSize and j == GridSize:
            grid[i,j] = grid[i,j-1] or grid[i-1,j-1] or grid[i-1,j]
        elif i == 0 and j == GridSize:
            grid[i,j] = grid[i,j-1] or grid[i+1,j-1] or grid[i+1,j]
        elif i == 0 and j != 0 and j!= GridSize:
            grid[i,j] = grid[i,j-1] or grid[i+1,j-1] or grid[i+1,j] or grid[i+1,j+1] or grid[i,j+1]
        elif j == GridSize and i != 0 and i!= GridSize:
            grid[i,j] = grid[i-1,j] or grid[i-1,j-1] or grid[i,j-1] or grid[i+1,j-1] or grid[i+1,j]
        elif i == GridSize and j != 0 and j!= GridSize:
            grid[i,j] = grid[i,j-1] or grid[i-1,j-1] or grid[i-1,j] or grid[i-1,j+1] or grid[i,j+1]
        elif j == 0 and i != 0 and i!= GridSize:
            grid[i,j] = grid[i-1,j] or grid[i-1,j+1] or grid[i,j+1] or grid[i+1,j+1] or grid[i+1,j]
        elif grid[i,j] == (0,0,0):
            grid[i,j] = grid[i,j]
# Out:
#   File "<ipython-input-5-467345cd0942>", line 6
#     elif !(i == 0 or j == 0 or i== GridSize or j == Gridsize):
#          ^
# SyntaxError: invalid syntax

# %%
from random import randint
from ipythonblocks import colors
from ipythonblocks import BlockGrid
from IPython.html import widgets
from IPython.display import display
from ipythonblocks import BlockGrid
from IPython.html.widgets import interact, interactive 
from IPython.display import clear_output

# %%
black = (0,0,0)
red = (255,0,0)
green = (0,128,0)
blue = (0,0,255)

def make_system(pop_density,blue_concentration,size):
    grid = BlockGrid(size, size, fill=(0,0,0),block_size=300/size) 
    total = size**2 #total= total amount of blocks
    empties = (total * pop_density)/100
    blues_reds = total - empties #blues_reds= total amount of agents
    blues = (blue_concentration * blues_reds)/100
    reds = blues_reds - blues
    
    #create random locations for blue agents
    count_blues = 0
    while count_blues < blues: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are made blue
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block blue if it is empty
            grid[row,col] = blue
            count_blues += 1
    
    #create random locations for red agents
    count_reds = 0
    while count_reds < reds: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are red
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block red if it is empty
            grid[row,col] = red
            count_reds += 1
    
    grid.show()
    return grid,pop_density,blue_concentration,size

# %%
def equal_color(a,b):
    if (a.red == b.red) and (a.green == b.green) and (a.blue == b.blue): 
        return True
    else:
        return False

# %%
def equal_black(a):
    if (a.red == 0) and (a.green == 0) and (a.blue == 0):
        return True
    else:
        return False

# %%
def find_movers(grid,threshold):
    movers_grid = []
    nulls_grid = []
    movers = len(movers_grid)
    nulls = len(nulls_grid)
    for i in range(grid.height):
        for j in range(grid.width):
            if satisfaction(grid,i,j) < threshold:
                movers_grid.append(satisfaction)
            elif grid[i,j].rgb == (0,0,0):
                nulls_grid.append(grid[i,j])
                
    return movers,nulls

# %%
def mover(grid,threshold,movers,nulls):
    for i in range(len(movers)):
        for null in nulls:
            original_color = grid[movers[0]].rgb #move the mover to a null and replace null with mover
            grid[null] = grid[movers[0]]
            grid[movers[0]] = black
            if satisfaction(grid, null[1],null[0]) < threshold:
                grid[null] = black #if mover is not satisfied move it back to where it was before
                grid[movers[0]] = original_color
                
                if nulls[len(nulls) - 1] == null: # if mover has no place to go then keep it where it is 
                    movers.remove(movers[0])
                else:
                    nulls.remove(null)
                    nulls.append(movers[0])
                    movers.remove(movers[0])
                    break

# %%
from random import randint
from ipythonblocks import colors
from ipythonblocks import BlockGrid
from IPython.html import widgets
from IPython.display import display
from IPython.html.widgets import interact, interactive
from IPython.display import clear_output

# %%
def equal_color(a,b):
    if (a.red,a.green,a.blue) == (b.red,b.green,b.blue):
        return True
    else:
        return False

# %%
def equal_black(a):
    if (a.red == 0) and (a.green == 0) and (a.blue == 0):
        return True
    else:
        return False

# %%
def satisfaction(grid,i,j):
    GridSize = grid.width - 1
    if grid[i,j].rgb != black:
        if i == 0 or j == 0 or i == GridSize or j == GridSize:
            #Corners
            if i == 0 and j == 0:
                sat = 0
                MaxNeighbors = 3
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1 
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j+1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif i == 0 and j == GridSize:
                sat = 0
                MaxNeighbors = 3
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif (i == GridSize and j == 0):
                sat = 0
                MaxNeighbors = 3
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif (i == GridSize and j == GridSize):
                sat = 0
                MaxNeighbors = 3
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
        elif (i != 0 and j != 0) or (i != 0 and j != GridSize) or (i != Gridsize and j != 0)\
        or (i != Gridsize and j != Gridsize):
            #Edge Pieces
            if i == 0 and j != 0 and j!=GridSize:
                sat = 0
                MaxNeigbors = 5
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif j == 0 and i!=0 and i!=GridSize:
                sat = 0
                if equal_color(grid[i+1,j],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif i == GridSize and j !=0 and j!=GridSize:
                sat = 0
                if equal_color(grid[i,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j+1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j+1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j-1],grid[i,j]): 
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
            elif j == GridSize and i!=0 and i != GridSize:
                sat = 0
                if equal_color(grid[i+1,j],grid[i,j]):
                    sat = sat+ 1
                elif equal_black(grid[i+1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i+1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i+1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j-1],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j-1]):
                    MaxNeighbors = MaxNeighbors - 1
                if equal_color(grid[i-1,j],grid[i,j]):
                    sat = sat + 1
                elif equal_black(grid[i-1,j]):
                    MaxNeighbors = MaxNeighbors - 1
                
                #Cells that have no neighbors: Avoid dividing by 0
                if MaxNeighbors == 0:
                    satisfaction = 0
                    return satisfaction
                #Cell with neighbors
                else:
                    satisfaction = float(sat) / float(MaxNeighbors)
                    return satisfaction
        else:
            #MIDDLE SQUARES
            sat = 0
            MaxNeighbors = 8
            if equal_color(grid[i+1,j],grid[i,j]):
                sat = sat+ 1
            elif equal_black(grid[i+1,j]):
                MaxNeighbors = MaxNeighbors - 1
            if equal_color(grid[i+1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j+1]):
                MaxNeighbors = MaxNeighbors - 1
            if equal_color(grid[i,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i,j+1]):
                MaxNeighbors = MaxNeighbors - 1
            if equal_color(grid[i-1,j+1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j+1]):
                MaxNeighbors = MaxNeighbors - 1
            if equal_color(grid[i-1,j],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j]):
                MaxNeighbors = MaxNeighbors - 1
            if equal_color(grid[i-1,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i-1,j-1]):
                MaxNeighbors = MaxNeighbors - 1
            if equal_color(grid[i, j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i, j-1]):
                MaxNeighbors = MaxNeighbors - 1
            if equal_color(grid[i+1,j-1],grid[i,j]):
                sat = sat + 1
            elif equal_black(grid[i+1,j-1]):
                MaxNeighbors = MaxNeighbors - 1
            
            #Cells that have no neighbors: Avoid dividing by 0
            if MaxNeighbors == 0:
                satisfaction = 0
                return satisfaction
            #Cell with neighbors
            else:
                satisfaction = float(sat) / float(MaxNeighbors)
                return satisfaction
    else:
        return None

# %%
black = (0,0,0)
red = (255,0,0)
green = (0,128,0)
blue = (0,0,255)

def make_grid(pop_density=5.,blue_concentration=5.,size=5.,threshold=0.,iteration=1.):
    grid = BlockGrid(size, size, fill=(0,0,0),block_size=300/size) 
    total = size**2 #total= total amount of blocks
    empties = (total * pop_density)/100
    blues_reds = total - empties #blues_reds= total amount of agents
    blues = (blue_concentration * blues_reds)/100
    reds = blues_reds - blues

        #create random locations for blue agents
    count_blues = 0
    while count_blues < blues: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are made blue
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block blue if it is empty
            grid[row,col] = blue
            count_blues += 1

        #create random locations for red agents
    count_reds = 0
    while count_reds < reds: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are red
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block red if it is empty
            grid[row,col] = red
            count_reds += 1


    while iteration > 0:
        movers_grid = []
        nulls_grid = []
        movers = len(movers_grid)
        nulls = range(len(nulls_grid))
        for i in range(grid.height):
            for j in range(grid.width):
                if satisfaction(grid,i,j) < threshold:
                    movers_grid.append(satisfaction)
                elif grid[i,j].rgb == (0,0,0):
                    nulls_grid.append(grid[i,j])


        for i in range(movers):
            for null in nulls:
                original_color = grid[movers[0]].rgb #move the mover to a null and replace null with mover
                grid[null] = grid[movers[0]]
                grid[movers[0]] = black
                if satisfaction(grid, null[1],null[0]) < threshold:
                    grid[null] = black #if mover is not satisfied move it back to where it was before
                    grid[movers[0]] = original_color

                    if nulls[len(nulls) - 1] == null: # if mover has no place to go then keep it where it is 
                        movers.remove(movers[0])
                    else:
                        nulls.remove(null)
                        nulls.append(movers[0])
                        movers.remove(movers[0])
                        break
        iteration = iteration - 1
        
    grid.show()
    
v = interact(make_grid,pop_density(0,100,0),blue_concentration(0,100,0),size(5,100,5),threshold(0,1,.01),iteration(0,100,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a1ff89433013> in <module>()
#      64     grid.show()
#      65
# ---> 66 v = interact(make_grid,pop_density(0,100,0),blue_concentration(0,100,0),size(5,100,5),threshold(0,1,.01),iteration(0,100,5))
#
# NameError: name 'pop_density' is not defined

# %%
make_grid(pop_density = 20,blue_concentration = 50,size = 20,threshold = 0.5,iteration = 20)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksacfc1c8d-e032-437a-a26e-8d8b4c54f962 td {border: 1px solid white;}</style><table id="blocksacfc1c8d-e032-437a-a26e-8d8b4c54f962" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 1]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 3]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 9]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 14]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [1, 2]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [1, 6]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (255, 0, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [1, 9]&#10;Color: (0, 0, 255)" style="width: 15px; height: 15px;background-color: rgb(0, 0, 255);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 255)" style="widt ...

# %%
def make_grid(pop_density=5,blue_concentration=5,size=5):
    grid = BlockGrid(size, size, fill=(0,0,0),block_size=300/size) 
    total = size**2 #total= total amount of blocks
    empties = (total * pop_density)/100
    blues_reds = total - empties #blues_reds= total amount of agents
    blues = (blue_concentration * blues_reds)/100
    reds = blues_reds - blues

        #create random locations for blue agents
    count_blues = 0
    while count_blues < blues: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are made blue
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block blue if it is empty
            grid[row,col] = blue
            count_blues += 1

        #create random locations for red agents
    count_reds = 0
    while count_reds < reds: #iterates through random locations of blockgrid
        row = randint(0,grid.height-1) #until the right amount of blocks are red
        col = randint(0,grid.width-1)
        if grid[row,col].rgb == black: #only makes the block red if it is empty
            grid[row,col] = red
            count_reds += 1

# %%
v = interact(make_grid,pop_density(0.,50.,0.),blue_concentration(0.,100.,0.),size(5.,100.,5.))

# %%
v = interact(make_grid)
